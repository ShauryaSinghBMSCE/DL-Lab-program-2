# %%
import tensorflow as tf
from tensorflow.keras import layers,models,optimizers
import numpy as np
import matplotlib.pyplot as plt

# %%
def create_data():
  X=np.random.randn(1000,10)
  y=np.random.randn(1000,1)
  return X,y

# %%
def create_model():
  model=models.Sequential([
      layers.Dense(50,activation="relu",input_shape=(10,)),
      layers.Dense(20,activation="relu"),
      layers.Dense(1)
  ])
  return model

# %%
def train_model_with_history(model,optimizer,X,y,batch_size,epochs,optimizer_name):
    model.compile(optimizer=optimizer,loss='mean_squared_error')
    history=[]
    for epoch in range(epochs):
        hist=model.fit(X,y,batch_size=batch_size,epochs=1,verbose=0)
        loss=hist.history['loss'][0]
        history.append(loss)
        print(f"Epoch {epoch+1}/{epochs}-{optimizer_name}Loss: {loss:.4f}")
    return history

# %%
X,y=create_data()

model_sgd=create_model()
model_adam=create_model()

optimizer_sgd=optimizers.SGD(learning_rate=0.01)
optimizer_adam=optimizers.Adam(learning_rate=0.01)

batch_size=32
epochs=50

print("\nTraining with SGD:")
sgd_loss=train_model_with_history(model_sgd,optimizer_sgd,X,y,batch_size,epochs,"SGD")

print("\nTraining with Adam:")
adam_loss=train_model_with_history(model_adam,optimizer_adam,X,y,batch_size,epochs,"Adam")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training with SGD:
# Epoch 1/50-SGDLoss: 1.0626
# Epoch 2/50-SGDLoss: 1.0430
# Epoch 3/50-SGDLoss: 1.0294
# Epoch 4/50-SGDLoss: 1.0178
# Epoch 5/50-SGDLoss: 1.0097
# Epoch 6/50-SGDLoss: 1.0031
# Epoch 7/50-SGDLoss: 0.9980
# Epoch 8/50-SGDLoss: 0.9900
# Epoch 9/50-SGDLoss: 0.9842
# Epoch 10/50-SGDLoss: 0.9836
# Epoch 11/50-SGDLoss: 0.9756
# Epoch 12/50-SGDLoss: 0.9722
# Epoch 13/50-SGDLoss: 0.9688
# Epoch 14/50-SGDLoss: 0.9648
# Epoch 15/50-SGDLoss: 0.9603
# Epoch 16/50-SGDLoss: 0.9538
# Epoch 17/50-SGDLoss: 0.9572
# Epoch 18/50-SGDLoss: 0.9511
# Epoch 19/50-SGDLoss: 0.9477
# Epoch 20/50-SGDLoss: 0.9443
# Epoch 21/50-SGDLoss: 0.9391
# Epoch 22/50-SGDLoss: 0.9366
# Epoch 23/50-SGDLoss: 0.9321
# Epoch 24/50-SGDLoss: 0.9276
# Epoch 25/50-SGDLoss: 0.9244
# Epoch 26/50-SGDLoss: 0.9221
# Epoch 27/50-SGDLoss: 0.9179
# Epoch 28/50-SGDLoss: 0.9157
# Epoch 29/50-SGDLoss: 0.9117
# Epoch 30/50-SGDLoss: 0.9073
# Epoch 31/50-SGDLoss: 0.9049
# Epoch 32/50-SGDLoss: 0.8997
# Epoch 33/50-SGDLoss: 0.8975
# Epoch 34/50-SGDLoss: 0.8927
# Epoch 35/50-SGDLoss: 0.8899
# Epoch 36/50-SGDLoss: 0.8855
# Epoch 37/50-SGDLoss: 0.8801
# Epoch 38/50-SGDLoss: 0.8794
# Epoch 39/50-SGDLoss: 0.8736
# Epoch 40/50-SGDLoss: 0.8705
# Epoch 41/50-SGDLoss: 0.8656
# Epoch 42/50-SGDLoss: 0.8648
# Epoch 43/50-SGDLoss: 0.8609
# Epoch 44/50-SGDLoss: 0.8541
# Epoch 45/50-SGDLoss: 0.8523
# Epoch 46/50-SGDLoss: 0.8476
# Epoch 47/50-SGDLoss: 0.8458
# Epoch 48/50-SGDLoss: 0.8400
# Epoch 49/50-SGDLoss: 0.8354
# Epoch 50/50-SGDLoss: 0.8317
#
# Training with Adam:
# Epoch 1/50-AdamLoss: 1.1052
# Epoch 2/50-AdamLoss: 1.0143
# Epoch 3/50-AdamLoss: 0.9875
# Epoch 4/50-AdamLoss: 0.9377
# Epoch 5/50-AdamLoss: 0.9132
# Epoch 6/50-AdamLoss: 0.8975
# Epoch 7/50-AdamLoss: 0.8584
# Epoch 8/50-AdamLoss: 0.8640
# Epoch 9/50-AdamLoss: 0.8385
# Epoch 10/50-AdamLoss: 0.8556
# Epoch 11/50-AdamLoss: 0.7709
# Epoch 12/50-AdamLoss: 0.7521
# Epoch 13/50-AdamLoss: 0.7426
# Epoch 14/50-AdamLoss: 0.7025
# Epoch 15/50-AdamLoss: 0.6662
# Epoch 16/50-AdamLoss: 0.6267
# Epoch 17/50-AdamLoss: 0.6042
# Epoch 18/50-AdamLoss: 0.5847
# Epoch 19/50-AdamLoss: 0.5492
# Epoch 20/50-AdamLoss: 0.5106
# Epoch 21/50-AdamLoss: 0.5081
# Epoch 22/50-AdamLoss: 0.4980
# Epoch 23/50-AdamLoss: 0.4531
# Epoch 24/50-AdamLoss: 0.5339
# Epoch 25/50-AdamLoss: 0.4590
# Epoch 26/50-AdamLoss: 0.4526
# Epoch 27/50-AdamLoss: 0.4356
# Epoch 28/50-AdamLoss: 0.4216
# Epoch 29/50-AdamLoss: 0.4238
# Epoch 30/50-AdamLoss: 0.4128
# Epoch 31/50-AdamLoss: 0.3852
# Epoch 32/50-AdamLoss: 0.3722
# Epoch 33/50-AdamLoss: 0.3382
# Epoch 34/50-AdamLoss: 0.3201
# Epoch 35/50-AdamLoss: 0.3606
# Epoch 36/50-AdamLoss: 0.3216
# Epoch 37/50-AdamLoss: 0.3272
# Epoch 38/50-AdamLoss: 0.3095
# Epoch 39/50-AdamLoss: 0.3138
# Epoch 40/50-AdamLoss: 0.3228
# Epoch 41/50-AdamLoss: 0.2825
# Epoch 42/50-AdamLoss: 0.2807
# Epoch 43/50-AdamLoss: 0.2660
# Epoch 44/50-AdamLoss: 0.3050
# Epoch 45/50-AdamLoss: 0.2892
# Epoch 46/50-AdamLoss: 0.2895
# Epoch 47/50-AdamLoss: 0.2676
# Epoch 48/50-AdamLoss: 0.2670
# Epoch 49/50-AdamLoss: 0.2534
# Epoch 50/50-AdamLoss: 0.2362

# %%
plt.plot(range(1,epochs+1),sgd_loss,label="SGD",color="blue")
plt.plot(range(1,epochs+1),adam_loss,label="Adam",color="orange")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("SGD vs Adam Optimizer:Loss Comparison")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.bar(range(1,epochs+1),sgd_loss,label="SGD",color="blue")
plt.bar(range(1,epochs+1),adam_loss,label="Adam",color="orange")
# Out:
# <BarContainer object of 50 artists>
